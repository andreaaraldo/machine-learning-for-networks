# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/andreaaraldo/machine-learning-for-networks/blob/master/02.regression/ignore.ipynb)

# %%
import pandas as pd # For dataframes (tables)
import numpy as np
import matplotlib.pyplot as plt # For plots
import sklearn.linear_model
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
dataset_to_use = 'B1'

# %%
mydatasets_folder = "/home/araldo/datasets"
df = pd.read_csv(mydatasets_folder +'/video-qoe-processed/df.'+
                 dataset_to_use+'_2.csv')

df=df.rename(columns={'label_num':'Resolution'})

# %%
df.head()
# Out:
#    RelativeTime  PacketsSent  PacketsReceived  BytesSent  BytesReceived  \
# 0           4.0            6               31       1668          36199
# 1           3.8           10               58       1935          77605
# 2           3.6           14               62       2842          75432
# 3           3.7           33              205       3569         278065
# 4           3.6            6               20       2036          27840
#
#           IPSrc0          IPDst0 Protocol0  PacketsSent0  PacketsReceived0  \
# 0   192.168.1.15     74.125.0.41      QUIC             2                26
# 1   192.168.1.15   173.194.31.91      QUIC             5                55
# 2   192.168.1.15  173.194.131.41      QUIC             7                54
# 3   192.168.1.15   173.194.31.91      QUIC            16               168
# 4   192.168.1.15     74.125.0.24      QUIC             4                20
#
#          ...          BufferValid  KBytesReceived  label Resolution  \
# 0        ...                 True          36.199  q360p        360
# 1        ...                 True          77.605  q144p        144
# 2        ...                 True          75.432  q144p        144
# 3        ...                 True         278.065  q360p        360
# 4        ...                 True          27.840  q360p        360
#
#   KBytesReceived_log  PacketsSent_log  PacketsReceived_log  BytesSent_log  \
# 0           3.589031         1.945910             3.465736       7.419980
# 1           4.351632         2.397895             4.077537       7.568379
# 2           4.323232         2.708050             4.143135       7.952615
# 3           5.627855         3.526361             5.327876       8.180321
# 4           3.326474         1.945910             3.044522       7.619233
#
#    BytesReceived_log BufferProgress_log
# 0          10.496814           0.015240
# 1          11.259400           0.007078
# 2          11.231000           0.006487
# 3          12.535614           0.005879
# 4          10.234265           0.007130
#
# [5 rows x 207 columns]

# %%
df_train, df_test = train_test_split(df, test_size=0.2)
df_test.head()
# Out:
#     RelativeTime  PacketsSent  PacketsReceived  BytesSent  BytesReceived  \
# 46           3.7           22              187       2782         259389
# 40           3.5           23              100       3439         138248
# 26           4.5           15              417       1699         566100
# 42           4.9           56              640       4409         870970
# 10           3.7           10               62       2313          82685
#
#            IPSrc0           IPDst0 Protocol0  PacketsSent0  PacketsReceived0  \
# 46   192.168.1.15    74.125.172.60      QUIC            19               187
# 40   192.168.1.15    74.125.172.60      QUIC            12                88
# 26   192.168.1.15      74.125.0.41      QUIC            13               412
# 42   192.168.1.15  173.194.185.232      QUIC            53               635
# 10   192.168.1.15  173.194.185.106      QUIC             8                61
#
#           ...          BufferValid  KBytesReceived   label Resolution  \
# 46        ...                 True         259.389   q480p        480
# 40        ...                 True         138.248   q360p        360
# 26        ...                 True         566.100  q1080p       1080
# 42        ...                 True         870.970   q720p        720
# 10        ...                 True          82.685   q480p        480
#
#    KBytesReceived_log  PacketsSent_log  PacketsReceived_log  BytesSent_log  \
# 46           5.558329         3.135494             5.236442       7.931285
# 40           4.929049         3.178054             4.615121       8.143227
# 26           6.338771         2.772589             6.035481       7.438384
# 42           6.769608         4.043051             6.463029       8.391630
# 10           4.415038         2.397895             4.143135       7.746733
#
#     BytesReceived_log BufferProgress_log
# 46          12.466088           0.009165
# 40          11.836812           0.010706
# 26          13.246528           0.007958
# 42          13.677364           0.031464
# 10          11.322806           0.011620
#
# [5 rows x 207 columns]

# %% [markdown]
# Let's split the dataset in 80% training set, 20% test set.

# %% [markdown]
# Try to run the code above multiple times.
#
# What do you observe? Is it a problem? How do you solve it?

# %% [markdown]
# To achieve reproducibility, set the seed

# %%
df_train, df_test = train_test_split(df, test_size=0.2, random_state=3)
df_test.head()
# Out:
#     RelativeTime  PacketsSent  PacketsReceived  BytesSent  BytesReceived  \
# 35           3.4           14               80       3265         105883
# 44           4.0            3               23       1465          32016
# 18           3.0           17              115       1219         156130
# 23           6.4           37              359       2651         495118
# 27           3.8           13               87        936         119179
#
#            IPSrc0          IPDst0 Protocol0  PacketsSent0  PacketsReceived0  \
# 35   192.168.1.15     74.125.0.24      QUIC            10                77
# 44   192.168.1.15   173.194.31.73      QUIC             0                23
# 18   192.168.1.15  173.194.31.120      QUIC            16               112
# 23   192.168.1.15     74.125.0.24      QUIC            35               356
# 27   192.168.1.15   173.194.31.73      QUIC            13                86
#
#           ...          BufferValid  KBytesReceived   label Resolution  \
# 35        ...                 True         105.883   q144p        144
# 44        ...                 True          32.016  q1080p       1080
# 18        ...                 True         156.130  q1080p       1080
# 23        ...                 True         495.118  q1080p       1080
# 27        ...                 True         119.179   q360p        360
#
#    KBytesReceived_log  PacketsSent_log  PacketsReceived_log  BytesSent_log  \
# 35           4.662335         2.708050             4.394449       8.091321
# 44           3.466236         1.386294             3.178054       7.290293
# 18           5.050689         2.890372             4.753590       7.106606
# 23           6.204796         3.637586             5.886104       7.883069
# 27           4.780627         2.639057             4.477337       6.842683
#
#     BytesReceived_log BufferProgress_log
# 35          11.570099           0.007130
# 44          10.374022           0.008356
# 18          11.958451           0.008812
# 23          13.112553           0.013305
# 27          11.688390           0.007166
#
# [5 rows x 207 columns]

# %% [markdown]
# ## Univariate Linear Regression

# %% [markdown]
# **Goal**: Predict `label_num` based on `KBytesReceived`

# %%
df_train[['KBytesReceived','Resolution']]
# Out:
#     KBytesReceived  Resolution
# 13         419.098         720
# 34         742.686         720
# 31         654.082         720
# 4           27.840         360
# 45         542.376        1080
# 46         259.389         480
# 15         140.375         144
# 37         512.026        1080
# 11         110.420         360
# 7          201.903         720
# 38         439.231        1080
# 30          50.504         144
# 33         143.000         240
# 43         173.786        1080
# 5          658.375         360
# 40         138.248         360
# 1           77.605         144
# 28         160.142         480
# 2           75.432         144
# 22         117.087         144
# 36          79.270         240
# 17         155.904        1080
# 26         566.100        1080
# 14         160.814        1080
# 29         191.514         480
# 20          79.344         144
# 32         122.320         240
# 41         280.018         720
# 39          96.111         480
# 10          82.685         480
# 19         859.621         720
# 21          81.684         144
# 0           36.199         360
# 8          172.740         240
# 3          278.065         360
# 24         225.479         240
# 42         870.970         720

# %% [markdown]
# Let's separate the independent variables $X$ from the dependent variables $y$

# %%
# .reshape(-1, 1) is needed since we have one single feature
X_train = df_train['KBytesReceived'].values.reshape(-1, 1);
y_train = df_train['Resolution'].values;

# %% [markdown]
# Let's first plot the data as they are, using a scatterplot.
#
# See [mathplotlib documentation](https://matplotlib.org/tutorials/introductory/lifecycle.html) for more info (optional).

# %%
fig, ax = plt.subplots() # This creates just a canvas
ax.scatter(X_train,y_train,color='red',s=1) # ax is the actual figure

# Customize the plot
ax.set(xlim=[-100,1200], ylim=[-100,1200], ylabel="Resolution",
      xlabel="KBytes received")

# Save it to the disk
fig.savefig('img/scatter.pdf')

# %% [markdown]
# Let's make a regression model "by hand".

# %%
my_slope = 1

# In order to plot a line, we need a set of values:
interval = np.array([-100,1200]).reshape(-1,1)
# We compute the prediction of our model
h_byhand = my_slope * interval

# %% [markdown]
# Let us add it to our plot

# %%
ax.plot(interval,h_byhand, label="Regression by hand")
ax.legend()


fig.savefig('img/QoE-prediction-regr-byhand.pdf')

# Show the updated figure (source https://stackoverflow.com/a/36267710/2110769)
fig

# %% [markdown]
# Try to find a better slope.

# %% [markdown]
# Let's train our first supervised learning model: an Ordinary Least Squares model.

# %%
model = sklearn.linear_model.LinearRegression()
model.fit(X_train,y_train)

h_values = model.predict(interval)

# %% [markdown]
# Let's plot the new model

# %%
ax.plot(interval,h_values, label="Linear Regression (OLS)")
ax.legend()

fig.savefig('img/QoE-prediction-OLS.pdf')
fig

# %%
print("theta_0 = ", model.intercept_, "; theta_1 = ", model.coef_)
# Out:
# theta_0 =  327.5557787452074 ; theta_1 =  [0.72611846]

# %% [markdown]
# ## Multivariate model

# %%
features=['PacketsSent', 'KBytesReceived', 'BufferHealth']
all_cols = features.copy()

all_cols.append('Resolution')

# %%
df[all_cols]
# Out:
#     PacketsSent  KBytesReceived  BufferHealth  Resolution
# 0             6          36.199     10.241165         360
# 1            10          77.605      4.446780         144
# 2            14          75.432      3.989780         144
# 3            33         278.065      3.700462         360
# 4             6          27.840      4.512780         360
# 5            58         658.375      9.454706         360
# 6            14          77.429      4.606780         144
# 7            33         201.903      5.301853         720
# 8            18         172.740      3.638107         240
# 9            23         181.476      5.314732         240
# 10           10          82.685      8.554780         480
# 11           12         110.420      4.189780         360
# 12           33         317.762      3.633641         480
# 13           37         419.098      1.495841         720
# 14           45         160.814      8.802211        1080
# 15           16         140.375      4.611142         144
# 16           20         140.715      5.590378         480
# 17           26         155.904      4.940168        1080
# 18           17         156.130      4.940168        1080
# 19           80         859.621      9.239532         720
# 20            6          79.344      4.173780         144
# 21            9          81.684      4.131780         144
# 22           17         117.087      4.202327         144
# 23           37         495.118      8.404533        1080
# 24           20         225.479      8.750780         240
# 25           20         202.123      4.490780         480
# 26           15         566.100      5.229260        1080
# 27           13         119.179      3.572139         360
# 28           15         160.142      4.589654         480
# 29           26         191.514      4.140251         480
# 30            9          50.504      3.525780         144
# 31           51         654.082      6.972004         720
# 32           22         122.320      4.230780         240
# 33           16         143.000      4.875208         240
# 34           58         742.686      9.068493         720
# 35           14         105.883      4.508780         144
# 36           19          79.270      4.190559         240
# 37           41         512.026      7.491003        1080
# 38           38         439.231     10.117581        1080
# 39           11          96.111      3.606904         480
# 40           23         138.248      6.210944         360
# 41           26         280.018     12.177060         720
# 42           56         870.970     15.992983         720
# 43           18         173.786      4.027776        1080
# 44            3          32.016      4.130790        1080
# 45           32         542.376     14.055979        1080
# 46           22         259.389      5.309531         480

# %%
X = df[features]
X_c = sm.add_constant(X)
y = df['Resolution']

model = sm.OLS(y,X_c).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Resolution   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     4.443
# Date:                Mon, 10 Feb 2020   Prob (F-statistic):            0.00832
# Time:                        00:45:43   Log-Likelihood:                -333.92
# No. Observations:                  47   AIC:                             675.8
# Df Residuals:                      43   BIC:                             683.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            282.8794    113.884      2.484      0.017      53.210     512.549
# PacketsSent       -0.5551      5.828     -0.095      0.925     -12.308      11.198
# KBytesReceived     0.5986      0.454      1.319      0.194      -0.317       1.514
# BufferHealth      18.3779     19.149      0.960      0.343     -20.240      56.996
# ==============================================================================
# Omnibus:                        6.692   Durbin-Watson:                   1.519
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.605
# Skew:                           0.916   Prob(JB):                       0.0368
# Kurtosis:                       2.871   Cond. No.                         859.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
features=['KBytesReceived']
all_cols = features.copy()

all_cols.append('Resolution')

X = df[features]
X_c = sm.add_constant(X)
y = df['Resolution']

model = sm.OLS(y,X_c).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Resolution   R-squared:                       0.220
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     12.70
# Date:                Mon, 10 Feb 2020   Prob (F-statistic):           0.000881
# Time:                        00:48:02   Log-Likelihood:                -334.43
# No. Observations:                  47   AIC:                             672.9
# Df Residuals:                      45   BIC:                             676.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            351.7606     67.000      5.250      0.000     216.815     486.706
# KBytesReceived     0.7115      0.200      3.563      0.001       0.309       1.114
# ==============================================================================
# Omnibus:                        6.717   Durbin-Watson:                   1.517
# Prob(Omnibus):                  0.035   Jarque-Bera (JB):                6.743
# Skew:                           0.922   Prob(JB):                       0.0343
# Kurtosis:                       2.786   Cond. No.                         506.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df[all_cols]
# Out:
#     KBytesReceived  Resolution
# 0           36.199         360
# 1           77.605         144
# 2           75.432         144
# 3          278.065         360
# 4           27.840         360
# 5          658.375         360
# 6           77.429         144
# 7          201.903         720
# 8          172.740         240
# 9          181.476         240
# 10          82.685         480
# 11         110.420         360
# 12         317.762         480
# 13         419.098         720
# 14         160.814        1080
# 15         140.375         144
# 16         140.715         480
# 17         155.904        1080
# 18         156.130        1080
# 19         859.621         720
# 20          79.344         144
# 21          81.684         144
# 22         117.087         144
# 23         495.118        1080
# 24         225.479         240
# 25         202.123         480
# 26         566.100        1080
# 27         119.179         360
# 28         160.142         480
# 29         191.514         480
# 30          50.504         144
# 31         654.082         720
# 32         122.320         240
# 33         143.000         240
# 34         742.686         720
# 35         105.883         144
# 36          79.270         240
# 37         512.026        1080
# 38         439.231        1080
# 39          96.111         480
# 40         138.248         360
# 41         280.018         720
# 42         870.970         720
# 43         173.786        1080
# 44          32.016        1080
# 45         542.376        1080
# 46         259.389         480

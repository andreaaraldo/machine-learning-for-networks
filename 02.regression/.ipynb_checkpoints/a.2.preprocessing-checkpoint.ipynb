# %% [markdown]
# <a href="https://colab.research.google.com/github/andreaaraldo/machine-learning-for-networks/blob/master/02.regression/a.2.preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Missing values

# %%
import pandas as pd
import missingno as msno

# %% [markdown]
# Load the dataset

# %%
# !wget https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/processed_datasets/requet/df.B1_2.with_missing_values.csv
# Out:
# --2020-03-03 17:49:07--  https://raw.githubusercontent.com/andreaaraldo/machine-learning-for-networks/master/processed_datasets/requet/df.B1_2.with_missing_values.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58689 (57K) [text/plain]
# Saving to: ‘df.B1_2.with_missing_values.csv’
#
# df.B1_2.with_missin 100%[===================>]  57.31K  --.-KB/s    in 0.03s
#
# 2020-03-03 17:49:12 (2.24 MB/s) - ‘df.B1_2.with_missing_values.csv’ saved [58689/58689]

# %%
df = pd.read_csv('df.B1_2.with_missing_values.csv')
df
# Out:
#     RelativeTime  PacketsSent  ...  BytesReceived_log  BufferProgress_log
# 0            4.0            6  ...          10.496814            0.015240
# 1            3.8           10  ...          11.259400            0.007078
# 2            3.6           14  ...          11.231000            0.006487
# 3            3.7           33  ...          12.535614            0.005879
# 4            3.6            6  ...          10.234265            0.007130
# 5            4.0           58  ...          13.397531            0.016666
# 6            3.6           14  ...          11.257130            0.008013
# 7            4.0           33  ...          12.215548            0.007958
# 8            4.0           18  ...          12.059549            0.005478
# 9            3.7           23  ...          12.108884            0.009356
# 10           3.7           10  ...          11.322806            0.011620
# 11           2.9           12  ...          11.612056            0.007488
# 12           3.9           33  ...          12.669061            0.005879
# 13           4.5           37  ...          12.945862            0.002470
# 14           4.3           45  ...          11.988010            0.013978
# 15           3.5           16  ...          11.852080            0.009220
# 16           4.7           20  ...          11.854499            0.009072
# 17           2.9           26  ...          11.957002            0.008812
# 18           3.0           17  ...          11.958451            0.008812
# 19           4.1           80  ...          13.664248            0.016203
# 20           3.6            6  ...          11.281561            0.006268
# 21           3.4            9  ...          11.310626            0.007301
# 22           2.8           17  ...          11.670681            0.007488
# 23           6.4           37  ...          13.112553            0.013305
# 24           4.7           20  ...          12.325987            0.013742
# 25           3.7           20  ...          12.216637            0.007130
# 26           4.5           15  ...          13.246528            0.007958
# 27           3.8           13  ...          11.688390            0.007166
# 28           3.7           15  ...          11.983822            0.008013
# 29           4.5           26  ...          12.162721            0.008289
# 30           4.3            9  ...          10.829828            0.004839
# 31           4.3           51  ...          13.390990            0.012014
# 32           3.6           22  ...          11.714404            0.007357
# 33           4.0           16  ...          11.870607            0.008467
# 34           3.9           58  ...          13.518030            0.014289
# 35           3.4           14  ...          11.570099            0.007130
# 36           3.0           19  ...          11.280628            0.007488
# 37           4.2           41  ...          13.146133            0.012980
# 38           4.9           38  ...          12.992783            0.016272
# 39           4.4           11  ...          11.473269            0.006384
# 40           3.5           23  ...          11.836812            0.010706
# 41           6.0           26  ...          12.542613            0.016492
# 42           4.9           56  ...          13.677364            0.031464
# 43           4.3           18  ...          12.065586            0.007301
# 44           4.0            3  ...          10.374022            0.008356
# 45           4.6           32  ...          13.203717            0.024172
# 46           3.7           22  ...          12.466088            0.009165
#
# [47 rows x 207 columns]

# %% [markdown]
# Note that there are some "Not a number" (`NaN`). If the dataset is big, we need a more systmatic way to detect missing values. The following [code](https://stackoverflow.com/a/37367344/2110769) gives the columns containing missing values

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['BytesSent']

# %% [markdown]
# It may also be useful to visualize where missing values are

# %%
msno.matrix(df)

# %% [markdown]
# ## Strategy 1: remove columns with missing values
#
# Just avoid using the columns that have missing values in your model

# %% [markdown]
# ## Strategy 2: Remove rows with missing values

# %%
df_nonull = df.dropna()

df_nonull.columns[df_nonull.isnull().any()].tolist()
# Out:
# []

# %% [markdown]
# We can now train and test the model on this dataset

# %%
........

# %% [markdown]
# ## Strategy 3: Imputting
